# %% [markdown]
# ## Supervised and experimental learning
# The objective of this exercise is to implement and validate a rule-based classifier.
#
#
# 1. Implement the corresponding rule-based classifier assigned to you in your selected programming language
#
#     a.The classifier must be able to read a supervised dataset in csv file format
#     b. Then, it should induce the set of rules from the training data set
#     c. The set of rules should be displayed in an interpretable way
#     d. The coverage and precision of each rule must be computed
#
# 2. Implement a rule interpreter being able to apply a set of classification rules to a validation/test dataset, obtaining the corresponding classification accuracy values.
#
# 3. Evaluate the set of rules obtained with the classifier, in at least 3 databases (one small, one medium and one large). You can use databases from UCI ML repository or other sources. Small ≈ (# instances ≤
#
#
# ### RISE ALGORITHM

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.datasets import load_wine
import matplotlib.pyplot as plt

# %%
origin_path = r"../databases/small/wine/wine.data"
columns_name = ['class','Alcohol','Malic acid','Ash','Alcalinity of ash','Magnesium','Total phenols','Flavanoids','Nonflavanoid phenols','Proanthocyanins','Color intensity','Hue','OD280/OD315 of diluted wines','Proline']

# %%
df = pd.read_csv(origin_path)
df.columns = columns_name
print(df.shape)
print(len(columns_name))
df.head(10)
# Out:
# (177, 14)
# 14
#    class  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 0      1    13.20        1.78  2.14               11.2        100
# 1      1    13.16        2.36  2.67               18.6        101
# 2      1    14.37        1.95  2.50               16.8        113
# 3      1    13.24        2.59  2.87               21.0        118
# 4      1    14.20        1.76  2.45               15.2        112
# 5      1    14.39        1.87  2.45               14.6         96
# 6      1    14.06        2.15  2.61               17.6        121
# 7      1    14.83        1.64  2.17               14.0         97
# 8      1    13.86        1.35  2.27               16.0         98
# 9      1    14.10        2.16  2.30               18.0        105
#
#    Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0           2.65        2.76                  0.26             1.28
# 1           2.80        3.24                  0.30             2.81
# ...

# %%
df.tail()
# Out:
#      class  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 172      3    13.71        5.65  2.45               20.5         95
# 173      3    13.40        3.91  2.48               23.0        102
# 174      3    13.27        4.28  2.26               20.0        120
# 175      3    13.17        2.59  2.37               20.0        120
# 176      3    14.13        4.10  2.74               24.5         96
#
#      Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 172           1.68        0.61                  0.52             1.06
# 173           1.80        0.75                  0.43             1.41
# 174           1.59        0.69                  0.43             1.35
# 175           1.65        0.68                  0.53             1.46
# 176           2.05        0.76                  0.56             1.35
#
#      Color intensity   Hue  OD280/OD315 of diluted wines  Proline
# 172              7.7  0.64                          1.74      740
# ...

# %%
df.describe()
# Out:
#             class     Alcohol  Malic acid         Ash  Alcalinity of ash  \
# count  177.000000  177.000000  177.000000  177.000000         177.000000
# mean     1.943503   12.993672    2.339887    2.366158          19.516949
# std      0.773991    0.808808    1.119314    0.275080           3.336071
# min      1.000000   11.030000    0.740000    1.360000          10.600000
# 25%      1.000000   12.360000    1.600000    2.210000          17.200000
# 50%      2.000000   13.050000    1.870000    2.360000          19.500000
# 75%      3.000000   13.670000    3.100000    2.560000          21.500000
# max      3.000000   14.830000    5.800000    3.230000          30.000000
#
#         Magnesium  Total phenols  Flavanoids  Nonflavanoid phenols  \
# count  177.000000     177.000000  177.000000            177.000000
# mean    99.587571       2.292260    2.023446              0.362316
# std     14.174018       0.626465    0.998658              0.124653
# ...

# %%
df.nunique()
# Out:
# class                             3
# Alcohol                         125
# Malic acid                      133
# Ash                              78
# Alcalinity of ash                62
# Magnesium                        52
# Total phenols                    97
# Flavanoids                      131
# Nonflavanoid phenols             39
# Proanthocyanins                 101
# Color intensity                 131
# Hue                              78
# OD280/OD315 of diluted wines    121
# Proline                         121
# dtype: int64

# %%
df.isnull().sum()
# Out:
# class                           0
# Alcohol                         0
# Malic acid                      0
# Ash                             0
# Alcalinity of ash               0
# Magnesium                       0
# Total phenols                   0
# Flavanoids                      0
# Nonflavanoid phenols            0
# Proanthocyanins                 0
# Color intensity                 0
# Hue                             0
# OD280/OD315 of diluted wines    0
# Proline                         0
# dtype: int64

# %%
correlation = df.corr()
sns.heatmap(correlation, xticklabels=correlation.columns, yticklabels=correlation.columns, annot = True)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(df)

# %%
sns.relplot(x='Magnesium',y='Ash', hue='class', data=df)

# %%
sns.distplot(df['Ash'])
# Out:
# /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Ash', ylabel='Density'>

# %%
sns.catplot(x='Magnesium', kind = 'box', data =df)

# %%
df_wine = load_wine

# Plot
plt.scatter(df_wine['data'][:, 0], df_wine['data'][:, 9], c=df_wine['target'])
plt.title('Wine recognition dataset')
plt.xlabel(df_wine['feature_names'][0])
plt.ylabel(df_wine['feature_names'][9])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/edisonjairbejaranosepulveda/Documents/AI_Master/Assigments/SEL/utils/test_notebook.ipynb Cell 10' in <cell line: 4>()
#       <a href='vscode-notebook-cell:/Users/edisonjairbejaranosepulveda/Documents/AI_Master/Assigments/SEL/utils/test_notebook.ipynb#ch0000006?line=0'>1</a> df_wine = load_wine
#       <a href='vscode-notebook-cell:/Users/edisonjairbejaranosepulveda/Documents/AI_Master/Assigments/SEL/utils/test_notebook.ipynb#ch0000006?line=2'>3</a> # Plot
# ----> <a href='vscode-notebook-cell:/Users/edisonjairbejaranosepulveda/Documents/AI_Master/Assigments/SEL/utils/test_notebook.ipynb#ch0000006?line=3'>4</a> plt.scatter(df_wine['data'][:, 0], df_wine['data'][:, 9], c=df_wine['target'])
# ...
